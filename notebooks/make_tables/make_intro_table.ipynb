# %% [markdown]
# # Format the LaTeX table introducing the sample

# %% [markdown]
# This notebook has a very simple and limited purpose, to construct a correctly formatted table of the sources in the LoVoCCS sample, with basic properties - this essentially is what we use in papers to mostly represent the knowledge we had going in to the analyses (i.e. few newly measured properties).

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the necessary files

# %% [markdown]
# This is the sample of clusters which is included in the paper:

# %%
samp = pd.read_csv("../../sample_files/X-LoVoCCSI.csv")
samp.head(5)
# Out:
#   LoVoCCSID   Name    MCXC_RA   MCXC_DEC  MCXC_Redshift  manual_xray_ra  \
# 0         1  A2029  227.73000   5.720000         0.0766      227.734300
# 1         2   A401   44.74000  13.580000         0.0739             NaN
# 2         4    A85   10.45875  -9.301944         0.0555             NaN
# 3         5  A3667  303.13000 -56.830000         0.0556      303.157313
# 4         7  A3827  330.48000 -59.950000         0.0980             NaN
#
#    manual_xray_dec  MCXC_R500
# 0         5.745471     1.3344
# 1              NaN     1.2421
# 2              NaN     1.2103
# 3       -56.845978     1.1990
# 4              NaN     1.1367

# %% [markdown]
# This file contains the coverage fractions calculated for each of the clusters:

# %%
cov_frac = pd.read_csv("../../outputs/results/mission_coverage_fractions.csv")
cov_frac.head(5)
# Out:
#    xmm_pointed_MCXC_R500  xmm_pointed_0.3Mpc  xmm_pointed_0.5Mpc  \
# 0                   1.00                 1.0                 1.0
# 1                   1.00                 1.0                 1.0
# 2                   0.99                 1.0                 1.0
# 3                   1.00                 1.0                 1.0
# 4                   1.00                 1.0                 1.0
#
#    xmm_pointed_1.0Mpc  xmm_pointed_2.0Mpc  chandra_MCXC_R500  chandra_0.3Mpc  \
# 0                 1.0                0.97               1.00             1.0
# 1                 1.0                0.98               1.00             1.0
# 2                 1.0                0.87               1.00             1.0
# 3                 1.0                0.82               0.97             1.0
# 4                 1.0                0.98               0.70             1.0
#
#    chandra_0.5Mpc  chandra_1.0Mpc  chandra_2.0Mpc  ...  swift_xrt_MCXC_R500  \
# 0             1.0            1.00            0.94  ...                 0.82
# 1             1.0            1.00            0.91  ...                 1.00
# 2             1.0            1.00            0.93  ...                 0.52
# 3             1.0            0.99            0.67  ...                 0.27
# 4             1.0            0.77            0.46  ...                 0.34
#
#    swift_xrt_0.3Mpc  swift_xrt_0.5Mpc  swift_xrt_1.0Mpc  swift_xrt_2.0Mpc  \
# 0              1.00              1.00              1.00              0.52
# 1              1.00              1.00              1.00              0.99
# 2              1.00              1.00              0.76              0.22
# 3              0.15              0.24              0.28              0.21
# 4              0.19              0.30              0.35              0.30
#
#    asca_MCXC_R500  asca_0.3Mpc  asca_0.5Mpc  asca_1.0Mpc  asca_2.0Mpc
# 0            1.00          1.0          1.0          1.0         0.88
# 1            1.00          1.0          1.0          1.0         0.94
# 2            0.99          1.0          1.0          1.0         0.54
# 3            0.97          1.0          1.0          1.0         0.78
# 4            0.00          0.0          0.0          0.0         0.00
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Generating the table string

# %% [markdown]
# Here we generate the string of LaTeX code that can be copied in as the data body of the table:

# %%
round_pos = 3

# %%
lines = ""
for row_ind, row in samp.iterrows():
    rel_name = row['Name']
    if rel_name == "RX J0820.9+0751/RXC J0821.0+0751":
        rel_name = "RXC J0821.0+0751"
        
    rel_lov_id = row['LoVoCCSID']
    rel_cov = cov_frac.iloc[row_ind]
    
    res_line = "{n} & {i} & ".format(n=rel_name, i=rel_lov_id)
    
    if np.isnan(row['manual_xray_ra']):
        ra = round(row['MCXC_RA'], round_pos)
        dec = round(row['MCXC_DEC'], round_pos)
        res_line += "{r} & {d} & ".format(r=ra, d=dec)
    else:
        ra = round(row['manual_xray_ra'], round_pos)
        dec = round(row['manual_xray_dec'], round_pos)
        res_line += r"{r}$^{{*}}$ & {d}$^{{*}}$ & ".format(r=ra, d=dec)
    
    res_line += "{} & ".format(round(row['MCXC_Redshift'], 3))
    if not rel_lov_id[-1].isdigit() and rel_lov_id[-1] != 'A':
        res_line += "- & "
    else:
        res_line += "{} & ".format(round(row['MCXC_R500'], 2))
    
    res_line += "{rc} & {fc} & {tc}".format(rc=rel_cov['xmm_pointed_MCXC_R500'],
                                            fc=rel_cov['xmm_pointed_0.5Mpc'],
                                            tc=rel_cov['xmm_pointed_1.0Mpc'])
        
    res_line += '\\\ \n'
    lines += res_line
print(lines)
# Out:
# A2029 & 1 & 227.734$^{*}$ & 5.745$^{*}$ & 0.077 & 1.33 & 1.0 & 1.0 & 1.0\\
# A401 & 2 & 44.74 & 13.58 & 0.074 & 1.24 & 1.0 & 1.0 & 1.0\\
# A85 & 4 & 10.459 & -9.302 & 0.056 & 1.21 & 0.99 & 1.0 & 1.0\\
# A3667 & 5 & 303.157$^{*}$ & -56.846$^{*}$ & 0.056 & 1.2 & 1.0 & 1.0 & 1.0\\
# A3827 & 7 & 330.48 & -59.95 & 0.098 & 1.14 & 1.0 & 1.0 & 1.0\\
# A3266 & 9 & 67.83$^{*}$ & -61.447$^{*}$ & 0.059 & 1.15 & 1.0 & 1.0 & 1.0\\
# A1651 & 10 & 194.84 & -4.19 & 0.085 & 1.13 & 1.0 & 1.0 & 1.0\\
# A754 & 11 & 137.28 & -9.67 & 0.054 & 1.14 & 1.0 & 1.0 & 1.0\\
# A3571 & 12 & 206.87 & -32.85 & 0.039 & 1.15 & 0.52 & 1.0 & 0.61\\
# A3112 & 13 & 49.49 & -44.24 & 0.075 & 1.13 & 1.0 & 1.0 & 1.0\\
# A399 & 14 & 44.46 & 13.05 & 0.072 & 1.12 & 1.0 & 1.0 & 1.0\\
# A2597 & 15 & 351.33 & -12.13 & 0.085 & 1.11 & 1.0 & 1.0 & 1.0\\
# A1650 & 18 & 194.671 & -1.757 & 0.085 & 1.1 & 1.0 & 1.0 & 1.0\\
# A3558 & 21 & 201.99 & -31.5 & 0.048 & 1.1 & 0.86 & 1.0 & 0.91\\
# A3695 & 22 & 308.694$^{*}$ & -35.824$^{*}$ & 0.089 & 1.06 & 1.0 & 1.0 & 1.0\\
# A3921 & 24 & 342.488 & -64.429 & 0.094 & 1.05 & 1.0 & 1.0 & 1.0\\
# A2426 & 26 & 333.636 & -10.372 & 0.098 & 1.04 & 1.0 & 1.0 & 1.0\\
# A3158 & 27 & 55.72 & -53.64 & 0.059 & 1.07 & 1.0 & 1.0 & 1.0\\
# RXC J1217.6+0339 & 28 & 184.42 & 3.66 & 0.077 & 1.05 & 1.0 & 1.0 & 1.0\\
# A2811 & 29 & 10.54 & -28.54 & 0.108 & 1.04 & 1.0 & 1.0 & 1.0\\
# A780 & 30 & 139.53 & -12.09 & 0.054 & 1.07 & 1.0 & 1.0 & 1.0\\
# A2420 & 31 & 332.58 & -12.18 & 0.085 & 1.04 & 1.0 & 1.0 & 1.0\\
# A1285 & 33 & 172.592$^{*}$ & -14.576$^{*}$ & 0.107 & 1.03 & 0.37 & 0.34 & 0.37\\
# A3911 & 35 & 341.577 & -52.729 & 0.097 & 1.03 & 1.0 & 1.0 & 1.0\\
# A2055 & 39 & 229.69 & 6.23 & 0.102 & 1.0 & 1.0 & 1.0 & 1.0\\
# A1750Centre & 41A & 202.707$^{*}$ & -1.862$^{*}$ & 0.085 & 1.0 & 1.0 & 1.0 & 1.0\\
# A1750North & 41B & 202.793$^{*}$ & -1.727$^{*}$ & 0.085 & - & 0.86 & 1.0 & 0.86\\
# A1750South & 41C & 202.557$^{*}$ & -2.094$^{*}$ & 0.085 & - & 0.22 & 0.07 & 0.22\\
# A3822 & 42 & 328.538 & -57.855 & 0.076 & 1.0 & 1.0 & 1.0 & 1.0\\
# A2941 & 45 & 26.26 & -53.014 & 0.117 & 0.97 & 1.0 & 1.0 & 1.0\\
# A2440Centre & 46A & 335.988$^{*}$ & -1.583$^{*}$ & 0.091 & 0.97 & 1.0 & 1.0 & 1.0\\
# A2440North & 46B & 336.063$^{*}$ & -1.517$^{*}$ & 0.091 & - & 0.94 & 1.0 & 0.92\\
# A2440South & 46C & 335.949$^{*}$ & -1.65$^{*}$ & 0.091 & - & 1.0 & 1.0 & 1.0\\
# A1644S & 48A & 194.287$^{*}$ & -17.409$^{*}$ & 0.047 & 0.99 & 0.99 & 1.0 & 0.99\\
# A1644N & 48B & 194.455$^{*}$ & -17.273$^{*}$ & 0.05 & - & 0.97 & 1.0 & 0.97\\
# A1348 & 49 & 175.35 & -12.27 & 0.119 & 0.95 & 0.99 & 1.0 & 1.0\\
# RBS 1847 & 51 & 334.502$^{*}$ & -65.181$^{*}$ & 0.095 & 0.96 & 1.0 & 1.0 & 1.0\\
# RXC J1215.4-3900 & 55 & 183.858$^{*}$ & -39.027$^{*}$ & 0.119 & 0.95 & 0.0 & 0.0 & 0.0\\
# A2351 & 58 & 323.568$^{*}$ & -13.439$^{*}$ & 0.09 & 0.96 & 1.0 & 1.0 & 1.0\\
# RXC J2218.2-0350 East & 60A & 334.573$^{*}$ & -3.825$^{*}$ & 0.09 & 0.95 & 1.0 & 1.0 & 1.0\\
# RXC J2218.2-0350 West & 60B & 334.667$^{*}$ & -3.78$^{*}$ & 0.09 & - & 1.0 & 1.0 & 1.0\\
# A2443 & 61 & 336.521$^{*}$ & 17.366$^{*}$ & 0.107 & 0.94 & 1.0 & 1.0 & 1.0\\
# A2050 & 63 & 229.08 & 0.1 & 0.118 & 0.93 & 1.0 & 1.0 & 1.0\\
# A1736 & 65 & 201.725 & -27.183 & 0.046 & 0.97 & 0.71 & 1.0 & 0.67\\
# A2384North & 66A & 328.091$^{*}$ & -19.546$^{*}$ & 0.094 & 0.94 & 0.85 & 1.0 & 0.83\\
# A2384South & 66B & 328.033$^{*}$ & -19.722$^{*}$ & 0.094 & - & 1.0 & 1.0 & 1.0\\
# A4059 & 67 & 359.26 & -34.76 & 0.048 & 0.96 & 0.86 & 1.0 & 0.8\\
# A3836 & 74 & 332.347 & -51.815 & 0.106 & 0.92 & 1.0 & 1.0 & 1.0\\
# A2533 & 75 & 346.81$^{*}$ & -15.224$^{*}$ & 0.111 & 0.92 & 1.0 & 1.0 & 1.0\\
# A2556 & 76 & 348.25 & -21.63 & 0.087 & 0.93 & 1.0 & 1.0 & 1.0\\
# A3126 & 80 & 52.16 & -55.71 & 0.085 & 0.92 & 1.0 & 1.0 & 1.0\\
# RXC J0049.4-2931 & 85 & 12.35 & -29.524 & 0.108 & 0.91 & 1.0 & 1.0 & 1.0\\
# A2554 & 89 & 348.08$^{*}$ & -21.504$^{*}$ & 0.111 & 0.91 & 1.0 & 1.0 & 1.0\\
# A2033 & 90 & 227.862$^{*}$ & 6.349$^{*}$ & 0.082 & 0.92 & 0.79 & 0.98 & 0.76\\
# A3395North & 93A & 96.867$^{*}$ & -54.439$^{*}$ & 0.051 & 0.93 & 0.89 & 1.0 & 0.84\\
# A3395South & 93B & 96.688$^{*}$ & -54.539$^{*}$ & 0.051 & - & 0.69 & 1.0 & 0.65\\
# A1606 & 94 & 191.15$^{*}$ & -11.993$^{*}$ & 0.096 & 0.91 & 1.0 & 1.0 & 1.0\\
# A2670 & 98 & 358.56 & -10.41 & 0.076 & 0.91 & 1.0 & 1.0 & 1.0\\
# A3532 & 99 & 194.334$^{*}$ & -30.363$^{*}$ & 0.055 & 0.92 & 1.0 & 1.0 & 0.97\\
# RXC J1139.4-3327 & 108 & 174.86 & -33.45 & 0.108 & 0.88 & 0.0 & 0.0 & 0.0\\
# RXC J0821.0+0751 & 119 & 125.259$^{*}$ & 7.864$^{*}$ & 0.11 & 0.86 & 1.0 & 1.0 & 1.0\\
# A3128 & 121 & 52.466$^{*}$ & -52.581$^{*}$ & 0.062 & 0.88 & 1.0 & 1.0 & 1.0\\
# A1023 & 122 & 157.0 & -6.8 & 0.118 & 0.86 & 0.0 & 0.0 & 0.0\\
# A3528 & 123 & 193.67 & -29.22 & 0.054 & 0.89 & 0.97 & 1.0 & 0.95\\
# A761 & 131 & 137.651 & -10.581 & 0.092 & 0.86 & 1.0 & 1.0 & 1.0\\
# A3825 & 134 & 329.605$^{*}$ & -60.414$^{*}$ & 0.075 & 0.87 & 1.0 & 1.0 & 1.0\\
